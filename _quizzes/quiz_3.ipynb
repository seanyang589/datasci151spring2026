# %% [markdown]
# # <span style="color:red; font-size:25px"> DATASCI 151 - Quiz #3 </span>

# %% [markdown]
# <font size = "4" >
# This quiz is open book
#
# <br>
#
# - You <span style="color:red"> CAN </span> use all material from the course repo
#
# - You should <span style="color:red"> NOT </span> use other resources outside the course repo.
#
# - You should <span style="color:red"> NOT </span> collaborate with other students
#
# <!-- - This is a graded quiz. Use of LLMs or any AI tools is <span style="color:red"> NOT ALLOWED. </span> -->
#
# - AI assistance is <span style="color:red"> NOT </span> permitted for this assignment.
#
# - To get full credit, the code should work as intended. But try to attempt every problem - you can still receive partial credit.
#
# <br>
#
# Print the following string:
#
# "I will abide by Emory's code of conduct"

# %%
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "4">
#
# **Q1** Looping over Filenames
#
# <font size = "3">
#
# **Finsh this problem without changing the file structure of the "quiz_3" folder**
#
# 1. Use the `os.listdir` function to create a list containing all the file names inside the "question_1" subfolder (which is inside the "quiz_data" folder).
#
# 2. Create an empty list called `df_list`.
#
# 3. Write a for-loop that loops over the elements of the list you created with `os.listdir`. For each file:
#
# - Read in the file using `pd.read_csv()`, creating a Pandas DataFrame object.
#
# - Append the DataFrame object to `df_list`
#
# 4. After the loop:
# - Print the number of DataFrames in `df_list` using a suitable Python command
#
# - Print the shape of the first DataFrame. **Note:** Suppose a single DataFrame called `df` has been defined. You can determine its shape by typing `df.shape`

# %%
import pandas as pd
import os

folder_path = "quiz_data/question_1"

# list files
file_list = os.listdir(folder_path)


df_list = []

# loop
for file in file_list:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)


print(len(df_list))          # number of DataFrames
print(df_list[0].shape)     # shape of first DataFrameimport pandas as pd
import os
import pandas as pd
import os

# path to folder
folder_path = "quiz_data/question_1"

# list files
file_list = os.listdir(folder_path)

# empty list
df_list = []

# loop
for file in file_list:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

# after loop
print(len(df_list))          # number of DataFrames
print(df_list[0].shape)     # shape of first DataFrame
# write your code below
import pandas as pd
import os

# path to folder
folder_path = "quiz_data/question_1"

# list files
file_list = os.listdir(folder_path)

# empty list
df_list = []

# loop
for file in file_list:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

# after loop
print(len(df_list))          # number of DataFrames
print(df_list[0].shape)     # shape of first DataFrame
# Out:
# 4
# (10080, 35)
# 4
# (10080, 35)
# 4
# (10080, 35)

# %% [markdown]
# <font size = "4">
#
# **Q2** Conversion of interest rates
#
# <font size = "3">
#
# **NOTE:** For this problem, interest rates are always given in decimal form. An interest rate of 25% corresponds to $r = 0.25$, an interest rate of 5% corresponds to $r = 0.05$, etc.
#
# Suppose you have a nominal annual interest rate $r_1$ that is compounded $n_1$ times per year. Then the value of $1 after one year is given by:
#
# $$ \left(1 + \frac{r_1}{n_1} \right)^{n_1}$$
#
# If you want to calculate the equivalent interest rate $r_2$ with a *different* compounding frequency $n_2$, you would equate the value of a dollar after one year in both cases:
#
# $$ \left(1 + \frac{r_2}{n_2} \right)^{n_2} = \left(1 + \frac{r_1}{n_1} \right)^{n_1}$$
#
# and then solve for $r_2$:
#
# \begin{align}
#  r_2 = n_2\cdot \left[ \left(1 + \frac{r_1}{n_1} \right)^{\frac{n_1}{n_2}} - 1 \right]
#  \end{align}
#
# - Using the equation above as a guide, write a function which calculates the value of $r_2$ based on the values of $r_1$, $n_1$, and $n_2$
#
# - Then evaluate the function to determine what interest rate we would need to convert a 10% interest rate ($r_1 = 0.1$) compounded daily ($n_1 = 365$) into one that is compounded monthly ($n_2 = 12$)?
#
# **NOTE: Read the note at the top of this question.**

# %%
# write your code below
def convert_rate(r1, n1, n2):
    return n2 * ((1 + r1/n1)**(n1/n2) - 1)

# evaluate for given values
r2 = convert_rate(0.1, 365, 12)
print(r2)
# Out:
# 0.10040401575731028

# %% [markdown]
# <font size="4">
# <p><strong>Q3</strong> Function with no return value</p>
# <font size="3">
# <p>Write a function that does <strong>not return any values</strong> (just like the <code>print</code> function).</p>
# <p>The function takes in <strong>4 arguments</strong>, with the following keywords:</p>
# <ul>
# <li><code>x_vals</code>: A sequence of numeric values (list, tuple, NumPy array, etc.)</li>
# <li><code>y_vals</code>: A sequence of numeric values of the same length as <code>x_vals</code></li>
# <li><code>x_label</code>: A string</li>
# <li><code>y_label</code>: A string</li>
# </ul>
# <p>The function creates a <strong>scatter plot</strong> of <code>y_vals</code> versus <code>x_vals</code>.<br>
# It should:</p>
# <ul>
# <li>Label the x-axis using <code>x_label</code></li>
# <li>Label the y-axis using <code>y_label</code></li>
# <li>Display the plot to the screen</li>
# </ul>
# <p>The function should have <strong>no return values</strong>.<br>
# (You may omit a return statement or explicitly write <code>return None</code>.)</p>
# </font></font>
#
# <font size = "4">
#
# - After defining your function in the blank cell below, read in the file "us_emission.csv" from the folder "quiz_data" and call your function twice to generate the **two** following scatter plots:
#
#     1. "Energy Consumption" vs. "CO2 Emissions"
#
#     2. "Year" vs. "CO2 Emissions"

# %%
import matplotlib.pyplot as plt

# define your function in this cell


def make_scatter(x_vals, y_vals, x_label, y_label):
    plt.scatter(x_vals, y_vals)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# define function
def make_scatter(x_vals, y_vals, x_label, y_label):
    plt.scatter(x_vals, y_vals)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()


df = pd.read_csv("quiz_data/us_emission.csv")

df.columns = df.columns.str.strip()

print(df.columns)

make_scatter(df["Energy Consumption"], df["CO2 Emissions"],
             "Energy Consumption", "CO2 Emissions")

make_scatter(df["Year"], df["CO2 Emissions"],
             "Year", "CO2 Emissions")
# Out:
# Index(['Year', 'Energy_consumption', 'CO2_emission', 'GDP'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy Consumption'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# <font size="4">
#
# **Q4:** A continous random variable $X$ is said to have an **exponential distribution with parameter $\lambda > 0$**, if its probability density function (pdf) $f_X$ has the form:
#
# $$ f_X(x) = \begin{cases} \lambda \mathrm{e}^{-\lambda x}\quad \textrm{when } x > 0\\
# 0\qquad\quad \textrm{when } x \leq 0\end{cases} $$
#
# - Complete the function below, implementing the probability density function $f_X$ as a Python function.
#
# - Your function should be able to handle any floating point number for the first argument `x`, and any **positive** floating point number for the the second argument `lam`.
#
# - Note: Python has a built-in keyword called `lambda`, so we cannot use that as the name of an input argument (it would cause a SyntaxError)

# %%
import numpy as np 

# complete the function below


def pdf_exp(x, lam):
    if x > 0:
        return lam * np.exp(-lam * x)
    else:
        return 0

# %% [markdown]
# <font size="4">
#
# **Q5:** Using `.iloc`
#
# <font size = "3">
#
# - Read in the dataset named "features.csv", assigning it to a DataFrame object named `df_cars`. Each row of the dataset corresponds to a type of car.
#
# - Using `.iloc`, extract the the columns corresponding to "displacement", "horsepower", and "weight" for **all** the cars. Assign the resulting DataFrame to a variable named `df_subset`.
#
# - For full points, the column indices should be of the form `start:stop` for appropriate integers `start` and `stop`.

# %%
import pandas as pd 

# write your code below

df_cars = pd.read_csv("features.csv")

df_subset = df_cars.iloc[:, 1:4]

print(df_subset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 5
#       1 import pandas as pd
#       3 # write your code below
# ----> 5 df_cars = pd.read_csv("features.csv")
#       7 df_subset = df_cars.iloc[:, 1:4]
#       9 print(df_subset)
#
# ...

# %% [markdown]
# <font size = "4">
#
# **Q6** Using `.iloc` and `.sort_values`
#
# <font size = "3">
#
# - Read in the dataset named "features.csv", assigning it to a DataFrame object named `df_cars`. Each row of the dataset corresponds to a type of car.
#
# - Using `.iloc`, extract the data for the "weight", "acceleration" and "vehicle_id" information for cars 28, 29, 30, 31, 32. Use the slicing operator `:` for both row and column indices. Assign the resulting DataFrame to a variable named `df_subset`.
#
# - Use the `.sort_values()` method to sort the subsetted data by "weight" in **descending** order (heaviest to lightest). Assign the the resulting DataFrame to a variable named `df_sorted`.

# %%
import pandas as pd 

# write your code below

df_cars = pd.read_csv("features.csv")

df_subset = df_cars.iloc[27:32, [4, 5, 6]]

df_sorted = df_subset.sort_values(by="weight", ascending=False)

print(df_sorted)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 5
#       1 import pandas as pd
#       3 # write your code below
# ----> 5 df_cars = pd.read_csv("features.csv")
#       7 df_subset = df_cars.iloc[27:32, [4, 5, 6]]
#       9 df_sorted = df_subset.sort_values(by="weight", ascending=False)
#
# ...
